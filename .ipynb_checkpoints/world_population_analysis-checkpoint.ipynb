# %% [markdown]
# # World Population Analysis
# ## by (Bilal Ahmed)
#
# ## Introduction:

# %%
#Importing all useful directories for this project:

import pandas as pd
import numpy as np
import zipfile
import pycountry
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns 

# %matplotlib inline

# %%
#Loading Dataset
df_population = pd.read_csv('world_population_visualisation.csv')
df_population.head(5)
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
df_population_old = df_population

# %%
#to round all float numbers in our dataset to two decimal places
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df_population = df_population.rename({'Country/Territory':'Country','CCA3':'Country_Code','Area (km²)': 'Area','Density (per km²)':'Density','Growth Rate':'Growth_Rate','World Population Percentage':'Population_Percentage'}, axis =1)

# %%
df_population = df_population.drop(['Rank','Capital'], axis = 1)

# %%
df_population = pd.melt(frame = df_population, id_vars = ['Country_Code','Country','Continent','Area','Density','Growth_Rate','Population_Percentage'], var_name = 'Year', value_name= 'Population')

# %%
df_population['Year'] = df_population['Year'].str[:4]

# %%
df_population = df_population.reindex(columns=['Country_Code', 'Country', 'Continent','Year', 'Population', 'Area', 'Density', 'Growth_Rate', 'Population_Percentage'])

# %%
df_population.head()
# Out:
#   Country_Code         Country Continent  Year  Population     Area  Density  \
# 0          AFG     Afghanistan      Asia  2022    41128771   652230    63.06
# 1          ALB         Albania    Europe  2022     2842321    28748    98.87
# 2          DZA         Algeria    Africa  2022    44903225  2381741    18.85
# 3          ASM  American Samoa   Oceania  2022       44273      199   222.48
# 4          AND         Andorra    Europe  2022       79824      468   170.56
#
#    Growth_Rate  Population_Percentage
# 0         1.03                   0.52
# 1         1.00                   0.04
# 2         1.02                   0.56
# 3         0.98                   0.00
# 4         1.01                   0.00

# %%
#To find out how many unique values in continent column
df_population['Continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Oceania', 'North America',
#        'South America'], dtype=object)

# %%
#Finding null values in each category and found none
df_population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1872 entries, 0 to 1871
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country_Code           1872 non-null   object
#  1   Country                1872 non-null   object
#  2   Continent              1872 non-null   object
#  3   Year                   1872 non-null   object
#  4   Population             1872 non-null   int64
#  5   Area                   1872 non-null   int64
#  6   Density                1872 non-null   float64
#  7   Growth_Rate            1872 non-null   float64
#  8   Population_Percentage  1872 non-null   float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 131.8+ KB

# %%
#finding dublicate values in dataset
df_population_duplicate = df_population[df_population.duplicated()]
df_population_duplicate

#No dublicate value found
# Out:
# Empty DataFrame
# Columns: [Country_Code, Country, Continent, Year, Population, Area, Density, Growth_Rate, Population_Percentage]
# Index: []

# %% [markdown]
# ## Correlation Matrix

# %%
#select column which have numerical datatypes
numeric_correlation = df_population.select_dtypes(include=['number'])
corr_df = numeric_correlation.corr()

plt.figure(figsize=(10,8))
sns.heatmap(corr_df, annot =True, cmap = 'magma', center = 0, linewidths = 0.5, linecolor = 'white')
plt.title('Correlation Matrix', color="#02485c", fontsize=16)
plt.show()

# %% [markdown]
# - High correlation between Population, Year and Population_Percentage.
# - Medium correlation between Area and Population and Area and Population_percentage.

# %% [markdown]
# ## What is continent-wise population ratio in 1970?

# %%
population_1970 = df_population.query('Year == "1970"').groupby('Continent')['Population'].sum()
pop_1970_percentage = population_1970.div(population_1970.sum()).mul(100)

plt.pie(pop_1970_percentage, labels = pop_1970_percentage.index, autopct='%1.1f%%', explode = (0.1, 0.1, 0.1, 0.1, 0.5, 0.1),shadow = True ,wedgeprops = {"edgecolor": "black"})
plt.title("Population of different Continent in 1970 (Millions)")
plt.show()

# %% [markdown]
# ## What is continent-wise population ratio in 2022?

# %%
population_2022 = df_population.query('Year == "2022"').groupby('Continent')['Population'].sum()
pop_2022_percentage = population_2022.div(population_2022.sum()).mul(100)

plt.pie(pop_2022_percentage, labels = pop_2022_percentage.index, autopct='%1.1f%%',shadow = True, explode = (0.1, 0.1, 0.1, 0.1, 0.5, 0.1) ,wedgeprops = {"edgecolor": "black"})
plt.title("Population of different Continent in 1970 (Millions)")
plt.show()

# %% [markdown]
# ## Top five most populated countries?

# %%
countries_population = df_population.query('Year == "2022"').groupby('Country')['Population'].sum()
df_most_poluted = countries_population.sort_values(ascending=False).head(5)
df_most_poluted = df_most_poluted.div(10**9)

colors = sns.color_palette("viridis")
ax = df_most_poluted.plot(kind = 'bar', color = colors, edgecolor = 'black', rot = 0, figsize = [8,6])
ax.bar_label(ax.containers[0], fontsize = 10)

plt.title('Top five most populated countries', fontsize=14)
plt.xlabel('Countries' ,fontsize = 10)
plt.ylabel('Population(Billions)' ,fontsize = 10)
plt.show()

# %% [markdown]
# ## How much percentage of population lives in top 5 most poluted Countries

# %%
df_population_old['World Population Percentage'].sort_values(ascending= False).head(5).sum()
# Out:
# 46.300000000000004

# %% [markdown]
# ## Top five least populated countries?

# %%
countries_population_l = df_population.query('Year == "2022"').groupby('Country')['Population'].sum()
df_least_poluted = countries_population_l.sort_values(ascending=True).head(5)

colors = sns.color_palette('magma')
ax = df_least_poluted.plot(kind = 'bar', color=colors, edgecolor = 'black', rot = 0, figsize = [8,6])
ax.bar_label(ax.containers[0], fontsize = 12)

plt.title('Top five Least populated countries', fontsize=14)
plt.xlabel('Countries' ,fontsize = 10)
plt.ylabel('Population' ,fontsize = 10)
plt.show()

# %% [markdown]
# ## How many country in each continent?

# %%
df_countries = df_population['Continent'].value_counts()

colors = sns.color_palette("viridis")
ax = df_countries.plot(kind = 'bar', color=colors,edgecolor = 'black', rot = 0, figsize = [8,6])
ax.bar_label(ax.containers[0], fontsize = 12)

plt.title('Countries in each continent', fontsize = 14)
plt.xlabel('Continents', fontsize = 10)
plt.ylabel('Number of countries', fontsize = 10)
plt.show()

# %% [markdown]
# ## Pakistan population over the years?

# %%
pak_population = df_population.query('Country == "Pakistan"').set_index('Year')['Population'].sort_index().div(10**6).plot(figsize = [14,5], marker='o', linestyle='-', linewidth=2, markersize=8);

plt.xlabel('Years', fontsize=14)
plt.ylabel('Population', fontsize=14)
plt.title('Pakistan population over the years(Millions)',color = "#02485c", fontsize=16)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## India and China population comparison over the year:

# %%
india_population = df_population.query('Country == "India"').set_index('Year')['Population'].sort_index().div(10**9).plot(figsize = [14,5], label = "India", marker='o', linestyle='-', linewidth=2, markersize=8);
china_population = df_population.query('Country == "China"').set_index('Year')['Population'].sort_index().div(10**9).plot(figsize = [14,5], label='China', marker='o', linestyle='-', linewidth=2, markersize=8);

plt.xlabel('Years', fontsize=14)
plt.ylabel('Population', fontsize=14)
plt.title('Comparison of India and China over the year(Billions)',color = "#02485c", fontsize=16)
plt.legend(fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Europe and Africa population comparison over the year.

# %%
# List of continents
continents = ["Europe", "Africa", "Asia", "North America", "South America"]
# Dictionary to store the data for each continent
population_data = {}
# Process data for each continent
for continent in continents:
    data = df_population.query(f'Continent == "{continent}"').groupby('Year')['Population'].sum().div(10**9)
    data.index = data.index.astype(int)
    population_data[continent] = data
# Create a figure and axis
plt.figure(figsize=(14, 8))
# Plotting the data with markers
for continent, data in population_data.items():
    data.plot(label=continent, marker='o', linestyle='-', linewidth=2, markersize=8)
# Adding titles and labels
plt.xlabel('Years', fontsize=14)
plt.ylabel('Population (Billions)', fontsize=14)
plt.title('Comparison of Europe and Africa Population Over the Years (Billions)', color="#02485c", fontsize=16)
plt.legend(fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
# Customize the ticks
min_year = min(data.index.min() for data in population_data.values())
max_year = max(data.index.max() for data in population_data.values())
plt.xticks(np.arange(min_year, max_year + 1, 5), fontsize=12)
plt.yticks(fontsize=12)
# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Population of top most populated countries yearly:

# %%
melted = df_population
melted['Year'] = melted['Year'].astype(int)

# %%
countries_list = ['China', 'India', 'United States']
years = [1970, 2000, 2022]
top_populated = melted.query('`Country` in @countries_list and Year in @years').groupby(['Year', 'Country'])['Population'
].sum().unstack()

# Plotting
fig, ax = plt.subplots(figsize=(16, 8))
top_populated.plot(kind='bar', stacked=True, edgecolor='black', rot=0, width=0.8, ax=ax)
# Add labels to bars
for container in ax.containers:
    ax.bar_label(container, labels=[f'{v.get_height():.2f}B' for v in container], fontsize=10)

# Customize the plot
ax.set_xlabel('Years', fontsize=14)
ax.set_ylabel('Population (Billions)', fontsize=14)
ax.set_title('Top Three Most Populated Countries in 1970, 2000, and 2022 (in Billions)', fontsize=16)
ax.legend(fontsize=12)
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
# Customize the ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Continent wise growth rate

# %%
data  = df_population['Growth_Rate']
plt.hist(data, bins=30, color='skyblue', edgecolor='black');

# %%
countries_growth= df_population.groupby('Continent')['Growth_Rate'].mean()
df_countries_growth = countries_growth.sort_values(ascending=False).head(5)

plt.figure(figsize=(8, 6))
# Using seaborn color palette for modern colors
colors = sns.color_palette("viridis", len(df_countries_growth))

ax = df_countries_growth.plot(kind='bar', color=colors, edgecolor='black', rot=0)
ax.set_ylabel('Growth Rate')
ax.set_title('Continent Wise Growth Rate')

# Setting y-axis limits to emphasize differences
ax.set_ylim([0.92, 1.04])  # Adjust the limits based on your data range

# Adding text labels on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height():.4f}', 
                (p.get_x() + p.get_width() / 2., 
                 
p.get_height()), 
                ha='center', va='center', 
                xytext=(0, 9), 
                textcoords='offset points')

plt.show()

# %% [markdown]
# ## How much percentage of population lives in top 5 most poluted Countries

# %%
df_high = df_population_old.loc[df_population_old['1980 Population']> 10**7]

df_high['1980 Growth Rate'] = df_high['1980 Population'].sub(df_high['1970 Population']).div(df_high['1970 Population'])
df_high['2022 Growth Rate'] = df_high['2022 Population'].sub(df_high['2010 Population']).div(df_high['2010 Population'])

df_high[['1980 Growth Rate','2022 Growth Rate']].head()
df_high.set_index('Country/Territory')[['1980 Growth Rate','2022 Growth Rate']].head()

plt.figure(figsize = [16,10])

sns.heatmap(df_high.set_index('Country/Territory')[['1980 Growth Rate', '2022 Growth Rate']],annot=True,fmt=".2F",cmap="RdYlGn_r");
# Out:
# /var/folders/5_/9_7tqpd15qv8j3wv9yj6p8bm0000gn/T/ipykernel_2495/962239801.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_high['1980 Growth Rate'] = df_high['1980 Population'].sub(df_high['1970 Population']).div(df_high['1970 Population'])
# /var/folders/5_/9_7tqpd15qv8j3wv9yj6p8bm0000gn/T/ipykernel_2495/962239801.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# ## Continent and population boxplot

# %%
## Box plot of population by continent
df_population.boxplot(column="Population", by='Continent', color = 'blue')
plt.style.use("tableau-colorblind10")
plt.xlabel("Continent")
plt.ylabel("Population (Log Scale)")
plt.yscale('log')
plt.title("Population by Continent")
plt.show()

# %% [markdown]
# ## Top 10 countries with most area?

# %%
# Extract top 10 countries by area
top_10_countries_area=df_population.drop_duplicates(subset=['Country']).sort_values(by = 'Area', ascending = False).set_index('Country')['Area'].head(10)
graph = top_10_countries_area.sort_values(ascending= True)

colors = sns.color_palette('magma')
ax = graph.plot(kind = 'barh', color=colors, edgecolor = 'black', rot = 0, figsize = [10,6])

plt.title('Top 10 Largest Countries', fontsize=12)
plt.xlabel('Area in Kms(million)')
plt.ylabel('Countries')
plt.show()

# %%
top_10_countries_area
# Out:
# Country
# Russia           17098242
# Canada            9984670
# China             9706961
# United States     9372610
# Brazil            8515767
# Australia         7692024
# India             3287590
# Argentina         2780400
# Kazakhstan        2724900
# Algeria           2381741
# Name: Area, dtype: int64

# %% [markdown]
# ## World Population increase in 50 Years:

# %%
a = df_population.groupby('Year')['Population'].sum().div(10**9)

colors = sns.color_palette('magma')
ax = a.plot(kind = 'bar', color=colors, edgecolor = 'black', rot = 0, figsize = [10,8])
ax.bar_label(ax.containers[0], fontsize = 12)

plt.title('World Population Growth in 50 Years',color = "#02485c", fontsize=12)
plt.xlabel('Years', fontsize=12)
plt.ylabel('population(Billions)', fontsize=12)
plt.show()
